# %%
import pandas as pd

# %%
df = pd.read_csv("../raw_data/clean_data.csv")

# %%
df.columns

# Step 1: Drop rows where the club is equal to 'Other'
df = df[df['club'] != 'Other']

def filter_position(df, club, position, max_count):
    filtered_df = df[(df['club'] == club) & (df[position] == 1)]
    return filtered_df.head(max_count)

def filter_and_append(avg_clubs, df, club, position, max_count):
    filtered_df = filter_position(df, club, position, max_count)
    return pd.concat([avg_clubs, filtered_df])

avg_clubs = pd.DataFrame()

for club in df['club'].unique():
    avg_clubs = filter_and_append(avg_clubs, df, club, 'goalkeeper', 2)
    avg_clubs = filter_and_append(avg_clubs, df, club, 'centerback', 3)
    avg_clubs = filter_and_append(avg_clubs, df, club, 'fullback', 4)
    avg_clubs = filter_and_append(avg_clubs, df, club, 'winger', 4)
    avg_clubs = filter_and_append(avg_clubs, df, club, 'midfielder', 5)
    avg_clubs = filter_and_append(avg_clubs, df, club, 'striker', 2)

# %%
df = avg_clubs.groupby(by='club').mean()

df.sort_values(by='club_rating', ascending=False, inplace=True)

# %%
def create_grouped_features(df):
    # Offensive Skills
    df['shooting'] = df[['fin', 'lon', 'fre', 'pen']].mean(axis=1)
    df['dribbling_control'] = df[['dri', 'fir', 'fla', 'tec']].mean(axis=1)
    df['passing_vision'] = df[['pas', 'vis', 'l th', 'cro', 'cor', 'otb']].mean(axis=1)
    
    # Defensive Skills
    df['tackling_interception'] = df[['tck', 'mar', 'pos', 'ant']].mean(axis=1)
    df['aerial_defense'] = df[['hea', 'jum', 'aer']].mean(axis=1)
    
    # Physical Attributes
    df['speed_agility'] = df[['acc', 'pac', 'agi']].mean(axis=1)
    df['strength_stamina'] = df[['str', 'sta', 'bal']].mean(axis=1)
    
    # Mental and Tactical Attributes
    df['decision_making'] = df[['dec', 'cmp']].mean(axis=1)
    df['work_ethic_effort'] = df[['wor', 'det', 'bra']].mean(axis=1)
    
    # Leadership and Teamwork
    df['leadership'] = df[['ldr', 'com']].mean(axis=1)
    df['teamwork'] = df['tea']
    
    # Goalkeeping Abilities
    df['goalkeeping_abilities'] = df[['han', 'ref', 'kic', 'thr', '1v1', 'ecc', 'cmd']].mean(axis=1)
    
    # Behavioral Attributes
    df['behavioral_attributes'] = df[['agg', 'pun']].mean(axis=1)
    
    # Player Traits
    df['player_traits'] = df['tro']
    
    # Create a new DataFrame with the grouped features
    dfgf = df[['shooting', 'dribbling_control', 'passing_vision', 'tackling_interception', 
               'aerial_defense', 'speed_agility', 'strength_stamina', 'decision_making', 
               'work_ethic_effort', 'leadership', 'teamwork', 'goalkeeping_abilities', 
               'behavioral_attributes', 'player_traits', 'club_rating']]
    
    return dfgf

# %%
df = create_grouped_features(df)

# %%
df
# Out:
#                        shooting  dribbling_control  passing_vision  \
# club
# Liverpool              9.437500          13.975000       11.533333
# Man City              10.500000          13.937500       11.558333
# R. Madrid             10.187500          13.512500       11.083333
# FC Bayern              9.937500          12.037500       10.600000
# Inter                 10.013889          12.069444       10.250000
# ...                         ...                ...             ...
# Goianésia              6.263158           8.618421        7.219298
# Gold Coast Knights     5.928571           8.321429        6.761905
# Gold Coast Utd (NPL)   4.173077           6.807692        5.794872
# Goldau                 4.328947           7.447368        5.649123
# Železničar (P)         6.944444           9.291667        8.685185
#
#                       tackling_interception  aerial_defense  speed_agility  \
# club
# Liverpool                         12.312500        8.366667      14.366667
# Man City                          10.750000        8.250000      14.733333
# R. Madrid                         10.975000        8.333333      13.933333
# FC Bayern                         10.400000        8.016667      13.783333
# Inter                             11.013889        8.444444      13.500000
# ...                                     ...             ...            ...
# Goianésia                          9.013158        6.789474      11.807018
# Gold Coast Knights                 8.214286        5.428571      12.142857
# Gold Coast Utd (NPL)               8.096154        6.538462      11.051282
# Goldau                             7.157895        5.350877      12.368421
# Železničar (P)                     9.222222        7.351852      11.537037
#
#                       strength_stamina  decision_making  work_ethic_effort  \
# club
# Liverpool                    13.850000        14.175000          14.616667
# Man City                     13.666667        13.825000          13.850000
# R. Madrid                    13.016667        12.775000          13.766667
# FC Bayern                    12.966667        14.000000          13.616667
# Inter                        13.481481        12.944444          14.296296
# ...                                ...              ...                ...
# Goianésia                     9.280702         9.815789          10.228070
# Gold Coast Knights            7.880952         9.821429           9.857143
# Gold Coast Utd (NPL)          7.564103         9.076923           8.512821
# Goldau                        7.263158         8.842105           8.877193
# Železničar (P)                9.222222        10.777778          10.000000
#
#                       leadership   teamwork  goalkeeping_abilities  \
# club
# Liverpool               7.175000  14.500000               3.342857
# Man City                6.550000  13.900000               3.392857
# R. Madrid               6.800000  12.900000               3.200000
# FC Bayern               6.450000  13.650000               3.278571
# Inter                   7.333333  14.611111               3.277778
# ...                          ...        ...                    ...
# Goianésia               5.921053   8.631579               2.932331
# Gold Coast Knights      6.000000   8.285714               3.193878
# Gold Coast Utd (NPL)    5.346154   7.153846               2.582418
# Goldau                  5.052632   7.000000               2.969925
# Železničar (P)          6.305556   9.777778               3.047619
#
#                       behavioral_attributes  player_traits  club_rating
# club
# Liverpool                          8.425000       3.250000       2042.0
# Man City                           7.525000       3.300000       2013.0
# R. Madrid                          7.125000       2.850000       2010.0
# FC Bayern                          7.200000       3.900000       1955.0
# Inter                              7.861111       3.500000       1917.0
# ...                                     ...            ...          ...
# Goianésia                          6.815789       2.947368       1156.0
# Gold Coast Knights                 6.285714       2.857143       1156.0
# Gold Coast Utd (NPL)               5.423077       2.615385       1156.0
# Goldau                             6.710526       3.368421       1156.0
# Železničar (P)                     6.805556       2.555556       1156.0
#
# [3739 rows x 15 columns]

# %%
counter_attacking_style = {
    'relevant_features': ['speed_agility', 'passing_vision', 'tackling_interception', 'shooting'],
    'weights': [0.25, 0.25, 0.25, 0.25]
}

# High-Pressing Havoc
high_pressing_style = {
    'relevant_features': ['speed_agility', 'tackling_interception', 'work_ethic_effort', 'leadership'],
    'weights': [0.25, 0.25, 0.25, 0.25]
}

# Defensive Fortress
defensive_style = {
    'relevant_features': ['aerial_defense', 'strength_stamina', 'leadership', 'tackling_interception'],
    'weights': [0.25, 0.25, 0.25, 0.25]
}

# Wing Dominance
wing_dominance_style = {
    'relevant_features': ['speed_agility', 'strength_stamina', 'decision_making', 'shooting'],
    'weights': [0.25, 0.25, 0.25, 0.25]
}

# Possession with Purpose
possession_with_purpose_style = {
    'relevant_features': ['teamwork', 'dribbling_control', 'passing_vision', 'decision_making'],
    'weights': [0.25, 0.25, 0.25, 0.25]
}

# Youthful Energy and High Intensity
youthful_energy_style = {
    'relevant_features': ['dribbling_control', 'speed_agility', 'strength_stamina', 'tackling_interception'],
    'weights': [0.25, 0.25, 0.25, 0.25]
}

# Midfield Maestros
midfield_maestros_style = {
    'relevant_features': ['decision_making', 'leadership', 'player_traits', 'behavioral_attributes'],
    'weights': [0.25, 0.25, 0.25, 0.25]
}

# %%
styles = {
    'counter_attack': counter_attacking_style, 
    'high_pressing': high_pressing_style, 
    'defensive': defensive_style, 
    'midfield_maestros': midfield_maestros_style,
    'wing_dominance': wing_dominance_style, 
    'possession_with_purpose': possession_with_purpose_style,
    'youthful_energy': youthful_energy_style}

# %%
def calculate_team_score(df, playing_style):
    relevant_features = playing_style['relevant_features']
    weights = playing_style['weights']

    # Filter DataFrame to include only relevant features
    relevant_df = df[relevant_features]

    # Normalize the relevant features to have values between 0 and 1
    normalized_df = (relevant_df - relevant_df.min()) / (relevant_df.max() - relevant_df.min())

    # Calculate the weighted sum for each team
    team_scores = (normalized_df * weights).sum(axis=1)
    
    # Making a DataFrame
    team_scores = pd.DataFrame(team_scores).sort_values(by=0, axis=0, ascending=False)

    # Get the team with the highest score
    best_team = team_scores.idxmax()

    return best_team, team_scores

# Create a DataFrame to store style scores for each team
all_style_scores = pd.DataFrame(index=df.index)

# Calculate the best team for each style and store the scores in the DataFrame
for style_name, style in styles.items():
    best_team, team_scores = calculate_team_score(df, style)
    
    # Renaming column
    team_scores = team_scores.rename(columns={0: style_name})
    
    # Merge the style scores with the overall DataFrame
    all_style_scores = pd.merge(all_style_scores, team_scores, left_index=True, right_index=True, how='outer')

    print(f"Best team for {style_name}: {best_team}")
    print("Team Scores:")
    print(team_scores)
    print()

# Calculate the average score for each team across all styles
all_style_scores['average_score'] = all_style_scores.mean(axis=1)

# Sort by the best average score
all_style_scores = all_style_scores.sort_values(by='average_score', ascending=False)


all_style_scores
# Out:
# Best team for counter_attack: style    Liverpool
# dtype: object
# Team Scores:
#                     style
# club
# Liverpool        0.943944
# Man City         0.941103
# A. Madrid        0.934565
# Barcelona        0.922905
# Tottenham        0.913312
# ...                   ...
# Rimba Star       0.140974
# Kelantan Tumpat  0.135125
# IKLS             0.132537
# Setia Perdana    0.127953
# Tunas            0.111423
#
# [3739 rows x 1 columns]
#
# Best team for high_pressing: style    Liverpool
# dtype: object
# Team Scores:
#                style
# club
# Liverpool   0.968765
# Milan       0.913942
# Inter       0.904666
# A. Madrid   0.903586
# Villarreal  0.895251
# ...              ...
# Besa FC     0.174129
# Sogi        0.171629
# Eimsbüttel  0.168967
# Tunas       0.156525
# Llangefni   0.154429
#
# [3739 rows x 1 columns]
#
# Best team for defensive: style    Milan
# dtype: object
# Team Scores:
#                   style
# club
# Milan          0.967041
# Liverpool      0.959544
# Tottenham      0.938201
# Sheff Utd      0.936672
# Villarreal     0.929105
# ...                 ...
# Risca          0.150072
# Besa FC        0.140444
# Llangefni      0.132621
# Rimba Star     0.104066
# Panchor Murai  0.101288
#
# [3739 rows x 1 columns]
#
# Best team for midfield_maestros: style    Liverpool
# dtype: object
# Team Scores:
#                        style
# club
# Liverpool           0.886291
# Inter               0.856643
# Real San Sebastián  0.852966
# Milan               0.840510
# Alanyaspor          0.836779
# ...                      ...
# Briton Ferry        0.268492
# Kiwi                0.260199
# Vaipuna             0.250830
# Llangefni           0.230865
# Lun Bawang          0.194986
#
# [3739 rows x 1 columns]
#
# Best team for wing_dominance: style    Man City
# dtype: object
# Team Scores:
#                     style
# club
# Man City         0.972339
# Paris SG         0.947073
# Liverpool        0.944773
# Barcelona        0.940304
# A. Madrid        0.925654
# ...                   ...
# Tunas            0.159962
# Rimba Star       0.158502
# Kelantan Tumpat  0.151270
# Tabuan U18s      0.140121
# Besa FC          0.130817
#
# [3739 rows x 1 columns]
#
# Best team for possession_with_purpose: style    Liverpool
# dtype: object
# Team Scores:
#                   style
# club
# Liverpool      0.978942
# Barcelona      0.977165
# Man City       0.957165
# A. Madrid      0.948238
# Tottenham      0.922723
# ...                 ...
# Perkasa        0.059560
# Setia Perdana  0.045689
# Tunas          0.042713
# BSRC           0.027457
# Besa FC        0.020368
#
# [3739 rows x 1 columns]
#
# Best team for youthful_energy: style    Liverpool
# dtype: object
# Team Scores:
#                     style
# club
# Liverpool        0.978489
# Man City         0.941552
# Barcelona        0.902622
# Zebre            0.898005
# A. Madrid        0.897570
# ...                   ...
# Risca            0.162309
# Kelantan Tumpat  0.148846
# Rimba Star       0.148771
# Tabuan U18s      0.137666
# Tunas            0.137366
#
# [3739 rows x 1 columns]
#
# Sorted Team Scores:
#              style_x   style_y   style_x   style_y   style_x   style_y  \
# club
# Liverpool   0.943944  0.968765  0.959544  0.886291  0.944773  0.978942
# Man City    0.941103  0.875700  0.866124  0.792079  0.972339  0.957165
# A. Madrid   0.934565  0.903586  0.897324  0.826592  0.925654  0.948238
# Tottenham   0.913312  0.887376  0.938201  0.812060  0.923918  0.922723
# Milan       0.875426  0.913942  0.967041  0.840510  0.893949  0.890170
# ...              ...       ...       ...       ...       ...       ...
# Risca       0.141114  0.211628  0.150072  0.287024  0.177860  0.094266
# Rimba Star  0.140974  0.199585  0.104066  0.355716  0.158502  0.071530
# Llangefni   0.142689  0.154429  0.132621  0.230865  0.189848  0.151831
# Besa FC     0.146013  0.174129  0.140444  0.324368  0.130817  0.020368
# Tunas       0.111423  0.156525  0.151070  0.328361  0.159962  0.042713
#
#                style  average_score
# club
# Liverpool   0.978489       0.951536
# Man City    0.941552       0.906580
# A. Madrid   0.897570       0.904790
# Tottenham   0.890046       0.898234
# Milan       0.884290       0.895047
# ...              ...            ...
# Risca       0.162309       0.174896
# Rimba Star  0.148771       0.168449
# Llangefni   0.170233       0.167502
# Besa FC     0.164116       0.157179
# Tunas       0.137366       0.155346
#
# [3739 rows x 8 columns]
# /var/folders/pv/hj9fs4fx3fn0k6t5l6qmlh6m0000gn/T/ipykernel_4047/2964392609.py:33: FutureWarning: Passing 'suffixes' which cause duplicate columns {'style_x'} in the result is deprecated and will raise a MergeError in a future version.
#   all_style_scores = pd.merge(all_style_scores, team_scores, left_index=True, right_index=True, how='outer')
# /var/folders/pv/hj9fs4fx3fn0k6t5l6qmlh6m0000gn/T/ipykernel_4047/2964392609.py:33: FutureWarning: Passing 'suffixes' which cause duplicate columns {'style_x'} in the result is deprecated and will raise a MergeError in a future version.
#   all_style_scores = pd.merge(all_style_scores, team_scores, left_index=True, right_index=True, how='outer')

# %%
### positions dataframe

def custom_scaler(dfgf_no_name):
    total_score = dfgf_no_name.sum(axis=1)
    scaled_dfgf_no_name = dfgf_no_name.div(total_score, axis=0)
    return scaled_dfgf_no_name
