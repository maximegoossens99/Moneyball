# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### Import Data

# %%
df = pd.read_csv('../raw_data/clean_data.csv', low_memory = False)

# %%
df.head()
# Out:
#               name       club  nat                               position  \
# 0  Kevin De Bruyne   Man City  BEL   M (RLC), AM (C)
# 1       Harry Kane  Tottenham  ENG   AM (C), ST (C)
# 2    Mohamed Salah  Liverpool  EGY   AM (RL), ST (C)
# 3       Sadio Mané  Liverpool  SEN   AM (RL), ST (C)
# 4    Son Heung-Min  Tottenham  KOR   M/AM (RL), ST (C)
#
#                            dob   age  height  weight       wage  \
# 0   28/6/1991 (29 years old)    29.0   181.0    68.0  1091000.0
# 1   28/7/1993 (27 years old)    26.0   188.0    86.0   948000.0
# 2   15/6/1992 (28 years old)    28.0   175.0    72.0   948000.0
# 3   10/4/1992 (28 years old)    28.0   175.0    69.0   854000.0
# 4   8/7/1992 (28 years old)     28.0   183.0    77.0   450000.0
#
#    last trans. fee  ...  midfielder  striker  winger  division_rating  \
# 0       60000000.0  ...           1        0       0             93.8
# 1              0.0  ...           0        1       0             93.8
# ...

# %%
# Filtrer les lignes où la nationalité (colonne "nat") est "BRA"
brazilian_players = df[df['nat'] == 'NOR']

# Afficher les noms des joueurs
brazilian_player_names = brazilian_players['name'].tolist()

# Afficher la liste des noms dans le notebook
brazilian_player_names
# Out:
# ['Martin Ødegaard',
#  'Sander Berge',
#  'Mohamed Elyounoussi',
#  'Joshua King',
#  'Kristoffer Ajer',
#  'Omar Elabdellaoui',
#  'Fredrik Gulbrandsen',
#  'Stefan Johansen',
#  'Mathias Normann',
#  'Ørjan Nyland',
#  'Leo Østigård',
#  'Anders Trondsen',
#  'Tokmac Nguen',
#  'Stefan Strandberg',
#  'Emil Bohinen',
#  'Magnus Wolff Eikrem',
#  'Martin Linnes',
#  'Torgeir Børven',
#  'Patrick Berg',
#  'Ohi Omoijuanfo',
#  'Martin Ellingsen',
#  'Jo Inge Berget',
#  'Vebjørn Hoff',
#  'Veton Berisha',
#  'Markus Henriksen',
#  'Eirik Hestad',
#  'André Hansen',
#  'Kristoffer Zachariassen',
#  'Thomas Lehne Olsen',
#  'Anders Konradsen',
#  'Marius Lode',
#  'Fredrik André Bjørkan',
#  'Aslak Witry',
#  'Pål André Helland',
#  'Fredrik Aursnes',
#  'Ulrik Saltnes',
#  'Aron Dønnum',
#  'Sondre Sørli',
#  'Birk Risa',
#  'Vegar Hedenstad',
#  'Gjermund Åsen',
#  'Haitam Aleesami',
#  'Sten Grytebust',
#  'Eirik Ulland Andersen',
#  'Runar Espejord',
#  'Martin Bjørnbak',
# ...
